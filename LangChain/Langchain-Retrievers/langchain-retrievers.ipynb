# %%
# !pip install langchain chromadb faiss-cpu openai tiktoken langchain_openai langchain-community wikipedia
# Out:
# Requirement already satisfied: langchain in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (1.3.14)
# Requirement already satisfied: chromadb in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (1.5.9)
# Requirement already satisfied: faiss-cpu in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (1.15.0)
# Requirement already satisfied: langchain-community in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (0.4.2)
# Requirement already satisfied: wikipedia in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (1.4.0)
# Requirement already satisfied: langchain-huggingface in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (1.2.2)
# Requirement already satisfied: sentence-transformers in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (5.7.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.9 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langchain) (1.5.3)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.5 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langchain) (1.2.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langchain) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.10.17)
# Requirement already satisfied: packaging>=23.2.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.9->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (3.8.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (15.0.1)
# Requirement already satisfied: anyio>=3.5.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (0.25.0)
# Requirement already satisfied: certifi in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (1.0.9)
# Requirement already satisfied: idna in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.18)
# Requirement already satisfied: h11>=0.16 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: build>=1.0.3 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: pydantic-settings>=2.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from chromadb) (2.15.0)
# Requirement already satisfied: pybase64>=1.4.1 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.52.1)
# Requirement already satisfied: numpy>=1.22.5 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from chromadb) (2.4.6)
# Requirement already satisfied: onnxruntime>=1.14.1 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from chromadb) (1.28.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from chromadb) (1.44.0)
# Requirement already satisfied: tokenizers>=0.13.2 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from chromadb) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from chromadb) (4.70.0)
# Requirement already satisfied: overrides>=7.3.1 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from chromadb) (1.83.0)
# Requirement already satisfied: bcrypt>=4.0.1 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from chromadb) (0.27.1)
# Requirement already satisfied: kubernetes>=28.1.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from chromadb) (36.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: rich>=10.11.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from chromadb) (15.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langchain-community) (3.14.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langchain-community) (2.0.51)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.5)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from pydantic-settings>=2.0->chromadb) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (2.7.0)
# Requirement already satisfied: greenlet>=1 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.4)
# Requirement already satisfied: beautifulsoup4 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from wikipedia) (4.15.0)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from langchain-huggingface) (1.27.0)
# Collecting click<9.0.0,>=8.4.2 (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface)
#   Using cached click-8.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: filelock>=3.10.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.32.2)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2026.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.6.0)
# Requirement already satisfied: colorama in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from click<9.0.0,>=8.4.2->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.4.6)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from sentence-transformers) (5.14.1)
# Requirement already satisfied: torch>=1.11.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from sentence-transformers) (2.13.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from sentence-transformers) (1.9.0)
# Requirement already satisfied: scipy>=1.0.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from sentence-transformers) (1.18.0)
# Requirement already satisfied: regex>=2025.10.22 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.7.19)
# Requirement already satisfied: safetensors>=0.8.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.8.0)
# Requirement already satisfied: pyproject_hooks in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2026.6.3)
# Requirement already satisfied: six>=1.9.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf>=4.25.8 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.6)
# Requirement already satisfied: googleapis-common-protos~=1.57 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.44.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-proto==1.44.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.65b0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.65b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from rich>=10.11.0->chromadb) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from rich>=10.11.0->chromadb) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: joblib>=1.4.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: setuptools>=77.0.3 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (83.0.0)
# Requirement already satisfied: sympy>=1.13.3 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from typer>=0.9.0->chromadb) (0.0.5)
# Requirement already satisfied: httptools>=0.8.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.8.0)
# Requirement already satisfied: watchfiles>=0.20 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.0)
# Requirement already satisfied: soupsieve>=1.6.1 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from beautifulsoup4->wikipedia) (2.9.2)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\Computer Courses\Agenetic-Ai\langchain_venv\Lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Using cached click-8.4.2-py3-none-any.whl (119 kB)
# Installing collected packages: click
#   Attempting uninstall: click
#     Found existing installation: click 8.4.1
#     Uninstalling click-8.4.1:
#       Successfully uninstalled click-8.4.1
# Successfully installed click-8.4.2
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# wikipedia-api 0.15.0 requires click==8.4.1, but you have click 8.4.2 which is incompatible.

# %% [markdown]
# ## Wikipedia Retriever

# %%
from langchain_community.retrievers import WikipediaRetriever

# %%
# Initialize the retriever (optional: set language and top_k)
retriever = WikipediaRetriever(top_k_results=2, lang="en")

# %%
# Define your query
query = "the geopolitical history of india and pakistan from the perspective of a chinese"

# Get relevant Wikipedia documents
docs = retriever.invoke(query)

# %%
docs

# %%
# Print retrieved content
for i, doc in enumerate(docs):
    print(f"\n--- Result {i+1} ---")
    print(f"Content:\n{doc.page_content}...")  # truncate for display

# %% [markdown]
# ## Vector Store Retriever

# %%
from langchain_community.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings
from langchain_core.documents import Document

# %%
# Step 1: Your source documents
documents = [
    Document(page_content="LangChain helps developers build LLM applications easily."),
    Document(page_content="Chroma is a vector database optimized for LLM-based search."),
    Document(page_content="Embeddings convert text into high-dimensional vectors."),
    Document(page_content="OpenAI provides powerful embedding models."),
]

# %%
# Step 2: Initialize embedding model
embedding_model = OpenAIEmbeddings()

# Step 3: Create Chroma vector store in memory
vectorstore = Chroma.from_documents(
    documents=documents,
    embedding=embedding_model,
    collection_name='my_collection'
)

# %%
# Step 4: Convert vectorstore into a retriever
retriever = vectorstore.as_retriever(search_kwargs={'k':2})

# %%
query = 'What is Chroma used for?'
results=retriever.invoke(query)

# %%
for i,doc in enumerate(results):
    print(f'\n--- Result {i+1} ---')
    print(doc.page_content)

# %%
# This is also gives same result
results = vectorstore.similarity_search(query, k=2)

# %%
for i,doc in enumerate(results):
    print(f'\n--- Result {i+1} ---')
    print(doc.page_content)

# %% [markdown]
# ## MMR
